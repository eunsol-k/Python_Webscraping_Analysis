# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.2
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: E:\Eunsol\Programs\comdo\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, intake, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: E:\Eunsol\Programs\comdo\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
print(f'request ver {requests.__version__}' )
print('beautifulsoup {}'.format(bs4.__version__))
# Out:
# request ver 2.32.2
# beautifulsoup 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스
req_param = {
    'sid': 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}

# requests 모듈 이용하여 http 통신
res = requests.get(url, headers=req_header)
# print(type(res))
# print(res.status_code) # 200
# print(res.ok) # True

if res.ok:
    html = res.text
    # parsing 위해 BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")

    '''
        <div class='sa_text'>
            <a href='https://n.news.naver.com/mnews/article/092/0002340904'>
    '''
    
    atag_list = soup.select("div.sa_text a.sa_text_title")
    for atag in atag_list:
        title = atag.text.strip() # 공백 제거
        url = atag['href']
        print(f'title: {title}\nurl: {url}')
        print('---------')
else:
    print(f'Error: {res.status_code}')
# Out:
# https://news.naver.com/section/105
# title: 한국금거래소 '티메프 사태' 미정산…모회사 아이티센 "대책마련"
# url: https://n.news.naver.com/mnews/article/008/0005072618
# ---------
# title: "애플, 무슨 일이야?"…韓, 아이폰 1차 출시국 기대감 '고조'
# url: https://n.news.naver.com/mnews/article/018/0005804686
# ---------
# title: 이공계 대학원생에 매달 80~110만원 지급…연구비 관리제도 개선
# url: https://n.news.naver.com/mnews/article/001/0014855246
# ---------
# title: 전기차 배터리 폭발→열폭주…신코팅법으로 억제한다[지금은 과학]
# url: https://n.news.naver.com/mnews/article/031/0000859284
# ---------
# title: SKT, 세계적 권위 정보 검색 학회서 AI 기술 우수성 입증
# url: https://n.news.naver.com/mnews/article/079/0003924527
# ---------
# title: '아마란스10' 200% 늘어난 더존비즈온, 하반기도 맑음
# url: https://n.news.naver.com/mnews/article/014/0005223355
# ---------
# title: "올해 스마트폰 출하 3.8%↑…1위 삼성, 애플과 격차 벌릴 것"
# url: https://n.news.naver.com/mnews/article/001/0014854918
# ---------
# title: 엔씨소프트, 서브컬처 게임 개발사 '빅게임스튜디오' 지분 및 판권 투자
# url: https://n.news.naver.com/mnews/article/014/0005223399
# ---------
# title: 코스피·코스닥 줄이어 서킷브레이커 발동
# url: https://n.news.naver.com/mnews/article/092/0002340932
# ---------
# title: 韓, 반도체 대중 수출 늘자… 中 “美 수출 제재 한계 드러나”
# url: https://n.news.naver.com/mnews/article/366/0001009937
# ---------
# title: ‘아재 입맛’인 줄 알았는데…믹스커피 MZ 업고 뜨나
# url: https://n.news.naver.com/mnews/article/092/0002340930
# ---------
# title: 네이버 '쇼핑 검색광고' 타고 온 '파워적립' 8년 만에 폐지
# url: https://n.news.naver.com/mnews/article/018/0005805500
# ---------
# title: 한국 양궁 금메달 5개 '싹쓸이'...비결은?
# url: https://n.news.naver.com/mnews/article/092/0002340929
# ---------
# title: [단독] 찜통더위 부른 북태평양 고기압…한중일 손잡고 예측 정확성 높인다
# url: https://n.news.naver.com/mnews/article/366/0001009933
# ---------
# title: 곤두박질치는 비트코인…'트럼프 약발' 보단 'R의 공포'
# url: https://n.news.naver.com/mnews/article/018/0005805497
# ---------
# title: 이통3사 2분기 합산 영업익 예상 1.3조…전환지원금 타격 적었다
# url: https://n.news.naver.com/mnews/article/003/0012710549
# ---------
# title: 배터리 화재 키우는 '열폭주' 억제 방법 찾았다
# url: https://n.news.naver.com/mnews/article/584/0000028179
# ---------
# title: 티빙, 토종 OTT 1위 굳히기.. 쿠플, EPL로 만회 나선다
# url: https://n.news.naver.com/mnews/article/014/0005223409
# ---------
# title: M7 주가폭락에 실망한 투자자…"인내심 한계 달했다"
# url: https://n.news.naver.com/mnews/article/092/0002340926
# ---------
# title: 유라클, 수요예측 경쟁률 1065.8대 1…공모가 2만1000원 확정
# url: https://n.news.naver.com/mnews/article/138/0002179208
# ---------
# title: "뭘로 결제했더라"…티메프 환불, 페이·카드 희비 엇갈린다
# url: https://n.news.naver.com/mnews/article/018/0005805482
# ---------
# title: 엔씨, 빅게임스튜디오 370억 규모 지분·판권 투자
# url: https://n.news.naver.com/mnews/article/003/0012710504
# ---------
# title: 아이폰, 이제야 한국 대우하나…신작 '1차 출시국' 포함된다
# url: https://n.news.naver.com/mnews/article/015/0005018184
# ---------
# title: 혼돈의 방송통신위원회와 ‘애국자가 없는 세상’
# url: https://n.news.naver.com/mnews/article/092/0002340921
# ---------
# title: 청라 화재서 촉발된 '中 배터리 포비아'…韓 3사 대체 가능성은 [소부장박대리]
# url: https://n.news.naver.com/mnews/article/138/0002179205
# ---------
# title: 말라리아·일본뇌염 모기 2배 넘게 급증…가장 확실한 예방법은
# url: https://n.news.naver.com/mnews/article/421/0007710891
# ---------
# title: “편의점 알바보다 열악한 처우” 이공계 석박사…연구생활장려금 지급, 숨통 트일까
# url: https://n.news.naver.com/mnews/article/016/0002345560
# ---------
# title: 전기차 배터리 열폭주 막을 방법 찾았다
# url: https://n.news.naver.com/mnews/article/366/0001009912
# ---------
# title: "美 상무부, 자율주행차 중국SW 사용 금지 규정 이달 발표 예정"
# url: https://n.news.naver.com/mnews/article/029/0002892817
# ---------
# title: 이공계 대학원생에 매달 80~110만원 지급…연구비 관리제도 개선
# url: https://n.news.naver.com/mnews/article/001/0014855246
# ---------
# title: 全 종목 '금메달' 석권 양궁…정의선 회장 40년 함께했다
# url: https://n.news.naver.com/mnews/article/092/0002340919
# ---------
# title: "언제까지 이렇게 덥나"…기상청 대신 인기 폭발한 날씨앱
# url: https://n.news.naver.com/mnews/article/008/0005073035
# ---------
# title: 美, 자율주행차에 중국산 SW·통신모듈 탑재 금지 추진
# url: https://n.news.naver.com/mnews/article/011/0004376131
# ---------
# title: 韓 해킹한 자료로 공장·지방개발 하려는 北... 北해커들 이곳 노린다
# url: https://n.news.naver.com/mnews/article/008/0005073031
# ---------
# title: 코오롱바이오텍, 골관절염 치료제 ‘TG-C’ 대량 생산 공정 개발
# url: https://n.news.naver.com/mnews/article/018/0005805447
# ---------
# title: “스마트폰 시장 3년 만에 성장세...삼성, 애플과 격차 벌릴 것”
# url: https://n.news.naver.com/mnews/article/366/0001009904
# ---------
# title: [제약바이오] 종근당, 바르는 소염진통제 케펨겔 출시 外
# url: https://n.news.naver.com/mnews/article/092/0002340918
# ---------
# title: '아마란스10' 200% 늘어난 더존비즈온, 하반기도 맑음
# url: https://n.news.naver.com/mnews/article/014/0005223355
# ---------
# title: 더존비즈온, 매출·영업이익 '쑥쑥'…"핵심사업 고른 성장"
# url: https://n.news.naver.com/mnews/article/648/0000027909
# ---------
# title: 애플, 버터플라이 키보드 집단소송 美 소비자에 보상금
# url: https://n.news.naver.com/mnews/article/366/0001009897
# ---------
# title: ‘살 파먹는 세균’ 잡는 약물 개발 [달콤한 사이언스]
# url: https://n.news.naver.com/mnews/article/081/0003470020
# ---------
# title: “이공계 석·박사 월 80~110만 원”…‘한국형 스타이펜드’ 윤곽 나왔다
# url: https://n.news.naver.com/mnews/article/056/0011775233
# ---------
# title: 자체 개발 SQL로 승부하는 '스마트마인드' [과기대X글로벌]
# url: https://n.news.naver.com/mnews/article/020/0003580328
# ---------
# title: "애플, 9월엔 인텔리전스 없이 아이폰16만 나온다"
# url: https://n.news.naver.com/mnews/article/092/0002340917
# ---------

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

def print_news(sid, section):    
    # 요청 Parameter
    req_param = {
    'sid': sid
    }
    url = 'https://news.naver.com/section/{sid}'.format(**req_param)
    
    print(f'======> {url} {section} 뉴스 <======')
    
    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }

    res = requests.get(url, headers=req_header)
    
    if res.ok:
        html = res.text
        # parsing 위해 BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
    
        '''
            <div class='sa_text'>
                <a href='https://n.news.naver.com/mnews/article/092/0002340904'>
        '''
        
        atag_list = soup.select("div.sa_text a.sa_text_title")
        for atag in atag_list:
            title = atag.text.strip() # 공백 제거
            url = atag['href']
            print(f'title: {title}\nurl: {url}')
            print('---------')
            
    else:
        print(f'Error: {res.status_code}')

# %%
print_news(103,section_dict[103])
# Out:
# ======> https://news.naver.com/section/103 생활/문화 뉴스 <======
# title: "에베레스트 등반 같은 오페라 '오텔로' 고국에 선보입니다"
# url: https://n.news.naver.com/mnews/article/018/0005805453
# ---------
# title: BMW코리아, 뉴 M4 컴페티션 M xDrive 쿠페·컨버터블 국내 출시
# url: https://n.news.naver.com/mnews/article/001/0014854688
# ---------
# title: 7월 수입차 등록, 작년보다 4%↑…하이브리드차, 절반 육박
# url: https://n.news.naver.com/mnews/article/001/0014854695
# ---------
# title: 지드래곤 ‘저스피스 재단’ 출범…마약 퇴치 나선다
# url: https://n.news.naver.com/mnews/article/366/0001009896
# ---------
# title: 롯데렌탈·케이카, 사업 확장 속도
# url: https://n.news.naver.com/mnews/article/015/0005017879
# ---------
# title: 당분간 폭염 계속…곳곳서 강한 소나기[날씨]
# url: https://n.news.naver.com/mnews/article/055/0001178631
# ---------
# title: 멸치 '조금', 생선 '한 토막'…초4 아들에 '저속노화' 식단 논란
# url: https://n.news.naver.com/mnews/article/031/0000859381
# ---------
# title: 8월 눈병·귓병 가장 많아…"물놀이 시 주의 필요"
# url: https://n.news.naver.com/mnews/article/584/0000028181
# ---------
# title: 소리 없이 찾아오는 ‘협심증’… 위험 알려주는 인공지능 개발돼
# url: https://n.news.naver.com/mnews/article/346/0000078428
# ---------
# title: [내일 날씨] "낮 최고 35도"… 전국 '폭염' 주의하세요
# url: https://n.news.naver.com/mnews/article/417/0001018906
# ---------
# title: 황보라, "얼굴에 뭘 붙인 거야?"...피부 진정된다지만 오래 놔뒀다간
# url: https://n.news.naver.com/mnews/article/296/0000080556
# ---------
# title: "30년 동안 잠을 안잤다고?"...밤낮 깨어있다는 40대女, 어떻게 가능?
# url: https://n.news.naver.com/mnews/article/296/0000080555
# ---------
# title: 아에로멕시코, '인천~멕시코시티' 직항 2년 만에 재개
# url: https://n.news.naver.com/mnews/article/421/0007710987
# ---------
# title: 7월 수입차 BMW 1위 탈환…벤츠·테슬라와 격차 벌려
# url: https://n.news.naver.com/mnews/article/092/0002340922
# ---------
# title: [르포]"쪄 죽겠다"…대청호 수해 쓰레기 수거 현장 더위와 전쟁
# url: https://n.news.naver.com/mnews/article/001/0014855300
# ---------
# title: 최소 열흘은 펄펄 끓을 한반도…역대 최고기온 '41도' 갈아 치울까
# url: https://n.news.naver.com/mnews/article/469/0000816123
# ---------
# title: [날씨] 이틀 연속 40℃ 육박 폭염...'한증막 더위' 10일 이상 더 간다
# url: https://n.news.naver.com/mnews/article/052/0002070328
# ---------
# title: [날씨] 한낮 체감온도 35도 안팎…내륙 중심 소나기
# url: https://n.news.naver.com/mnews/article/422/0000674747
# ---------
# title: [르포] "냉토시 안에도 땀이 줄줄"…부산 피서지도 '헉헉'
# url: https://n.news.naver.com/mnews/article/001/0014855252
# ---------
# title: "피 한 방울로 신장이식 환자 이식 거부 반응 확인 가능"
# url: https://n.news.naver.com/mnews/article/346/0000078424
# ---------
# title: 유전자 돌연변이 없는 난소암, 면역항암제 치료 가능성 제시
# url: https://n.news.naver.com/mnews/article/346/0000078422
# ---------
# title: 올해 열대야 12일 달해…'사상 최악 폭염' 2018년보다 많아
# url: https://n.news.naver.com/mnews/article/001/0014855230
# ---------
# title: 5초 만에 폐암 확인… ‘이 손가락 테스트’ 아시나요?
# url: https://n.news.naver.com/mnews/article/346/0000078419
# ---------
# title: [날씨] 서울 낮 체감 35℃...찜통 더위? 시원한 계곡은 달라요!
# url: https://n.news.naver.com/mnews/article/052/0002070314
# ---------
# title: "샤넬은 살 만큼 샀다"…요즘 잘나가는 '금수저룩' [안혜원의 명품의세계]
# url: https://n.news.naver.com/mnews/article/015/0005018165
# ---------
# title: 혈당 조절 위해 ‘이 식습관’ 바꿨더니... 체중에 큰 변화가?
# url: https://n.news.naver.com/mnews/article/296/0000080550
# ---------
# title: '이 암' 극복하고, 아버지와 1600km 자전거 완주 목표… 英 소년, 사연 봤더니?
# url: https://n.news.naver.com/mnews/article/346/0000078418
# ---------
# title: [날씨] 전국 대부분 지역 폭염경보…요란한 소나기 유의
# url: https://n.news.naver.com/mnews/article/422/0000674739
# ---------
# title: 찬 음식 먹었더니 설사 줄줄… ‘이때’ 먹으면 도움 되는 음식 3
# url: https://n.news.naver.com/mnews/article/346/0000078416
# ---------
# title: 태극기 휘날린 대한민국 양궁… 현대차그룹 첨단기술 ‘적중’
# url: https://n.news.naver.com/mnews/article/020/0003580327
# ---------
# title: [날씨] 이틀째 40℃ 육박 극한 폭염...도로 표면 온도는?
# url: https://n.news.naver.com/mnews/article/052/0002070300
# ---------
# title: 폭염에 지난주 평일 4백여명 응급실행…4명 사망
# url: https://n.news.naver.com/mnews/article/374/0000396098
# ---------
# title: “국내에서만 유행하는 일본뇌염바이러스(5형), 기존 바이러스보다 더 치명적”
# url: https://n.news.naver.com/mnews/article/022/0003957238
# ---------
# title: [날씨] 밤낮 가리지 않는 무더위…전국 폭염특보 발효 중
# url: https://n.news.naver.com/mnews/article/422/0000674731
# ---------
# title: "주말에만 5명 숨졌다"…'살인 폭염'에 올해 온열질환 사망자 13명
# url: https://n.news.naver.com/mnews/article/011/0004376111
# ---------
# title: 계곡에 사는 가재를 꼬시는 엉뚱한 노래
# url: https://n.news.naver.com/mnews/article/047/0002441996
# ---------
# title: 나이 들수록 男이 신경 써야 할 것들...컨디션 최상으로 유지하려면?
# url: https://n.news.naver.com/mnews/article/296/0000080548
# ---------
# title: 한국에만 있는 '5형 일본뇌염', 기존 백신으론 방어 못해
# url: https://n.news.naver.com/mnews/article/584/0000028176
# ---------
# title: 배우 황승언, 수영복 입고 ‘애플힙’ 뒤태 뽐내… 평소 먹는 식단 뭘까?
# url: https://n.news.naver.com/mnews/article/346/0000078414
# ---------
# title: ‘안정형 협심증’도 관상동맥질환 예측 성공
# url: https://n.news.naver.com/mnews/article/016/0002345496
# ---------
# title: [날씨] 서울 체감 35℃...찜통 더위? 시원한 계곡은 달라요!
# url: https://n.news.naver.com/mnews/article/052/0002070282
# ---------
# title: [날씨] '덥다 더워', 극한 폭염 속 도로 표면 온도 50℃ 육박
# url: https://n.news.naver.com/mnews/article/052/0002070281
# ---------

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=798173&no=5&amp;weekday=thu'
}
img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]
for img_url in img_urls:
    res = requests.get(img_url , headers=req_header)
    if res.ok:
        img_data = res.content # binary 데이터 추출
        file_name = os.path.basename(img_url)
        with open(file_name, 'wb') as file: # with open 같이 쓸 경우 file 연 후 close 자동으로 생성
            print(f'writing to {file_name} ({len(img_data):,} bytes)')
            file.write(img_data)
# Out:
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg (299319)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg (163333)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg (182530)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
import os

url = 'https://comic.naver.com/webtoon/detail?titleId=817945&no=37&week=mon'
req_header = {
    'referer': url
}
res = requests.get(url)
if res.ok: #200
    pass
else:
    print(res.status_code)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %% [markdown]
# ### 4. 단축 URL 생성하는 Open API 사용하기
# * urllib 사용

# %%
import os
import sys
import urllib.request

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값
encText = urllib.parse.quote("https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-")
data = "url=" + encText
url = "https://openapi.naver.com/v1/util/shorturl"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값

origin_url = "https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-"

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': 'V',
    'X-Naver-Client-Secret': 'y_',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

res = requests.get(url, params=payload, headers=headers)
items_data = res.json()['items']
#print(items_data)

items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])

    items_list.append(item_list)
    item_list = []

print(items_list)

with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
